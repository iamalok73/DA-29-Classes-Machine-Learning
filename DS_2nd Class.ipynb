# %% [markdown]
# # Regression
#
# - Regression is a form of Predictive modeling Techniques.
# - Which is Investigate the reationship between Dependent (Target) and independend (Predictor).
# - This Techniques used for forcasting , Time Series Analyais and find Casual Reltionships between the Variable.

# %% [markdown]
#   1. Linear Regrssion -
#         - Simple Linear Regrsion , Multiple Linear Regrssion.
#   2. Polynomial Regrssion
#   3. Ridge and Lasso Regrssion
#   4. Step Wise Regression
#   5. Logistic Regrssion

# %% [markdown]
# # Regrssion Metrics
#
#     1. MAE
#     2. MSE
#     3. RMSE
#     4. R2- Score
#     5. Adjusted R2 Score

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
print("All import Sucessfully.")
# Out:
# All import Sucessfully.

# %%
df = pd.read_csv(r"C:\Users\AlokVerma\Desktop\ML DATA\canada_per_capita_income.csv")
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df.columns
# Out:
# Index(['year', 'per capita income (US$)'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     47 non-null     int64
#  1   per capita income (US$)  47 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 884.0 bytes

# %%
df.describe()
# Out:
#               year  per capita income (US$)
# count    47.000000                47.000000
# mean   1993.000000             18920.137063
# std      13.711309             12034.679438
# min    1970.000000              3399.299037
# 25%    1981.500000              9526.914515
# 50%    1993.000000             16426.725480
# 75%    2004.500000             27458.601420
# max    2016.000000             42676.468370

# %%
X = df[["year"]]

# %%
y = df[['per capita income (US$)']]

# %%
X
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
y
# Out:
#     per capita income (US$)
# 0               3399.299037
# 1               3768.297935
# 2               4251.175484
# 3               4804.463248
# 4               5576.514583
# 5               5998.144346
# 6               7062.131392
# 7               7100.126170
# 8               7247.967035
# 9               7602.912681
# 10              8355.968120
# 11              9434.390652
# 12              9619.438377
# 13             10416.536590
# 14             10790.328720
# 15             11018.955850
# 16             11482.891530
# 17             12974.806620
# 18             15080.283450
# 19             16426.725480
# 20             16838.673200
# 21             17266.097690
# 22             16412.083090
# 23             15875.586730
# 24             15755.820270
# 25             16369.317250
# 26             16699.826680
# 27             17310.757750
# 28             16622.671870
# 29             17581.024140
# 30             18987.382410
# 31             18601.397240
# ...

# %%
plt.plot(X,y)
plt.xlabel("year")
plt.ylabel("pci")
# Out:
# Text(0, 0.5, 'pci')

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
y_pred
# Out:
# array([[ -134.55966672],
#        [  693.9054085 ],
#        [ 1522.37048373],
#        [ 2350.83555895],
#        [ 3179.30063417],
#        [ 4007.7657094 ],
#        [ 4836.23078462],
#        [ 5664.69585984],
#        [ 6493.16093506],
#        [ 7321.62601029],
#        [ 8150.09108551],
#        [ 8978.55616073],
#        [ 9807.02123595],
#        [10635.48631118],
#        [11463.9513864 ],
#        [12292.41646162],
#        [13120.88153685],
#        [13949.34661207],
#        [14777.81168729],
#        [15606.27676251],
#        [16434.74183774],
#        [17263.20691296],
#        [18091.67198818],
#        [18920.1370634 ],
#        [19748.60213863],
#        [20577.06721385],
#        [21405.53228907],
#        [22233.9973643 ],
#        [23062.46243952],
#        [23890.92751474],
#        [24719.39258996],
#        [25547.85766519],
#        [26376.32274041],
#        [27204.78781563],
#        [28033.25289085],
#        [28861.71796608],
#        [29690.1830413 ],
# ...

# %%
plt.plot(X,y)
plt.plot(X,y_pred)
plt.scatter(X,y_pred)
plt.xlabel("year")
plt.ylabel("pci")
# Out:
# Text(0, 0.5, 'pci')

# %%
cof = model.coef_

# %%
inter = model.intercept_

# %%
year = int(input("Enter the year: "))

result = cof*year + inter

print(result)
# Out:
# Enter the year:  2030
# [[49573.34484664]]

# %%
model.score(X,y)*100
# Out:
# 89.0916917957032

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error,r2_score

# %%
mae = mean_absolute_error(y,y_pred)
mae
# Out:
# 3088.866427771443

# %%
mse = mean_squared_error(y,y_pred)
mse
# Out:
# 15462739.061504772

# %%
r2 = r2_score(y,y_pred)
r2
# Out:
# 0.890916917957032

# %%
r2_again = r2_score(y_pred,y)

# %%
r2_again
# Out:
# 0.8775608815543572
