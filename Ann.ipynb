# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dense
# Out:
# C:\Users\AlokVerma\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv(r"C:\Users\AlokVerma\Desktop\archive\WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
#  17  PaymentMethod     7043 non-null   str
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   str
#  20  Churn             7043 non-null   str
# dtypes: float64(1), int64(2), str(18)
# memory usage: 1.9 MB

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"],errors = "coerce")

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.drop(columns="customerID",inplace=True)

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0              Yes           Electronic check           29.85         29.85
# 1               No               Mailed check           56.95       1889.50
# 2              Yes               Mailed check           53.85        108.15
# 3               No  Bank transfer (automatic)           42.30       1840.75
# 4              Yes           Electronic check           70.70        151.65
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes

# %%
X = df.iloc[:,:19]
y = df.iloc[:,-1]

# %%
X.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges'],
#       dtype='str')

# %%
X = pd.get_dummies(X,columns=['gender','Partner', 'Dependents',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod'],drop_first= True)

# %%
# X = X.astype(float)
# y = y.replace({"Yes": 1, "No": 0})

# %%
y
# Out:
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
# Name: Churn, Length: 7032, dtype: str

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
X = sc.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_pred = dt.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,dt_pred)
# Out:
# 0.7246876346402413

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf_pred = rf.predict(X_test)

# %%
accuracy_score(y_test,rf_pred)
# Out:
# 0.7850064627315813

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
kn = KNeighborsClassifier()

# %%
kn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
kn_pred = kn.predict(X_test)
# Out:
# C:\Users\AlokVerma\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\AlokVerma\anaconda3\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#         "wmic CPU Get NumberOfCores /Format:csv".split(),
#         capture_output=True,
#         text=True,
#     )
#   File "C:\Users\AlokVerma\anaconda3\Lib\subprocess.py", line 554, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AlokVerma\anaconda3\Lib\subprocess.py", line 1039, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         pass_fds, cwd, env,
#                         ^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#                         gid, gids, uid, umask,
#                         ^^^^^^^^^^^^^^^^^^^^^^
#                         start_new_session, process_group)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\AlokVerma\anaconda3\Lib\subprocess.py", line 1554, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#                              # no special security
#                              ^^^^^^^^^^^^^^^^^^^^^
#     ...<4 lines>...
#                              cwd,
#                              ^^^^
#                              startupinfo)
#                              ^^^^^^^^^^^^

# %%
accuracy_score(y_test,kn_pred)
# Out:
# 0.7647565704437742

# %%
X = X.astype(int)
y = y.replace({"Yes": 1, "No": 0})

y = y.astype(int)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
classifier = Sequential()

# %%
classifier.add(Dense(units=6,activation="relu",kernel_initializer="uniform"))
classifier.add(Dense(units=6,activation="relu",kernel_initializer="uniform"))
classifier.add(Dense(units=6,activation="relu",kernel_initializer="uniform"))

# %%
classifier.add(Dense(units=1,activation="sigmoid",kernel_initializer="uniform"))

# %%
classifier.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
history = classifier.fit(X_train, y_train, batch_size=10, epochs=50)
# Out:
# Epoch 1/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.7311 - loss: 0.5190
# Epoch 2/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7686 - loss: 0.4418
# Epoch 3/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7983 - loss: 0.4352
# Epoch 4/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8009 - loss: 0.4306
# Epoch 5/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7956 - loss: 0.4288
# Epoch 6/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7962 - loss: 0.4265
# Epoch 7/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7988 - loss: 0.4245
# Epoch 8/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7988 - loss: 0.4241
# Epoch 9/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7994 - loss: 0.4232
# Epoch 10/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7983 - loss: 0.4224
# Epoch 11/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8000 - loss: 0.4217
# Epoch 12/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7990 - loss: 0.4204
# Epoch 13/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7990 - loss: 0.4203
# Epoch 14/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7983 - loss: 0.4187
# Epoch 15/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7986 - loss: 0.4200
# Epoch 16/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7992 - loss: 0.4188
# Epoch 17/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.7998 - loss: 0.4193
# Epoch 18/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8000 - loss: 0.4191
# Epoch 19/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7996 - loss: 0.4180
# Epoch 20/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8009 - loss: 0.4185
# Epoch 21/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7966 - loss: 0.4176
# Epoch 22/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8022 - loss: 0.4178
# Epoch 23/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8024 - loss: 0.4171
# Epoch 24/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7988 - loss: 0.4176
# Epoch 25/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8007 - loss: 0.4168
# Epoch 26/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - accuracy: 0.8028 - loss: 0.4165
# Epoch 27/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8017 - loss: 0.4165
# Epoch 28/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8017 - loss: 0.4163
# Epoch 29/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.8020 - loss: 0.4155
# Epoch 30/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8022 - loss: 0.4157
# Epoch 31/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.7988 - loss: 0.4150
# Epoch 32/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8032 - loss: 0.4146
# Epoch 33/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8053 - loss: 0.4155
# Epoch 34/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8017 - loss: 0.4145
# Epoch 35/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8003 - loss: 0.4144
# Epoch 36/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.7998 - loss: 0.4142
# Epoch 37/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8017 - loss: 0.4134
# Epoch 38/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8005 - loss: 0.4136
# Epoch 39/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8049 - loss: 0.4122
# Epoch 40/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8026 - loss: 0.4133
# Epoch 41/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8049 - loss: 0.4122
# Epoch 42/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8049 - loss: 0.4126
# Epoch 43/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8037 - loss: 0.4122
# Epoch 44/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.8053 - loss: 0.4134
# Epoch 45/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8032 - loss: 0.4126
# Epoch 46/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8043 - loss: 0.4121
# Epoch 47/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8028 - loss: 0.4122
# Epoch 48/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8024 - loss: 0.4121
# Epoch 49/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.8028 - loss: 0.4124
# Epoch 50/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8049 - loss: 0.4116

# %%
loss, accuracy = classifier.evaluate(X_test, y_test)
print("Accuracy:", accuracy)
# Out:
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7992 - loss: 0.4243
# Accuracy: 0.7992244958877563

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)
# Out:
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step

# %%
from sklearn.metrics import accuracy_score

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7992244722102542

# %%
print(history.history['accuracy'])
# Out:
# [0.731054961681366, 0.7686266303062439, 0.7983443140983582, 0.8008915185928345, 0.7955847978591919, 0.7962216138839722, 0.7987688183784485, 0.7987688183784485, 0.7994056344032288, 0.7983443140983582, 0.800042450428009, 0.7989811301231384, 0.7989811301231384, 0.7983443140983582, 0.7985565662384033, 0.7991933822631836, 0.7998301982879639, 0.800042450428009, 0.7996178865432739, 0.8008915185928345, 0.7966461181640625, 0.802165150642395, 0.8023774027824402, 0.7987688183784485, 0.8006792664527893, 0.8028019666671753, 0.8017405867576599, 0.8017405867576599, 0.8019528985023499, 0.802165150642395, 0.7987688183784485, 0.8032264709472656, 0.8053491711616516, 0.8017405867576599, 0.8002547025680542, 0.7998301982879639, 0.8017405867576599, 0.8004670143127441, 0.8049246668815613, 0.8025896549224854, 0.8049246668815613, 0.8049246668815613, 0.8036510348320007, 0.8053491711616516, 0.8032264709472656, 0.804287850856781, 0.8028019666671753, 0.8023774027824402, 0.8028019666671753, 0.8049246668815613]

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()
