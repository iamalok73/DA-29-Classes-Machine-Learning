# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\AlokVerma\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv(r"C:\Users\AlokVerma\Desktop\ML DATA\Telco_Cusomer_Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"],errors = "coerce")

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (7032, 21)

# %%
df.drop(columns=["customerID"],inplace=True)

# %%
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
X = df.iloc[:,0:19]

# %%
y = df.iloc[:,-1]

# %%
X.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges'],
#       dtype='str')

# %%
X = pd.get_dummies(X, columns=['gender', 'Partner', 'Dependents', 
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod'],drop_first=True)

# %%
X.head(2)
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 0              0       1           29.85         29.85        False
# 1              0      34           56.95       1889.50         True
#
#    Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 0         True           False             False
# 1        False           False              True
#
#    MultipleLines_No phone service  MultipleLines_Yes  ...  \
# 0                            True              False  ...
# 1                           False              False  ...
#
#    StreamingTV_No internet service  StreamingTV_Yes  \
# 0                            False            False
# 1                            False            False
#
#    StreamingMovies_No internet service  StreamingMovies_Yes  \
# 0                                False                False
# 1                                False                False
#
#    Contract_One year  Contract_Two year  PaperlessBilling_Yes  \
# 0              False              False                  True
# 1               True              False                 False
#
#    PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                  False                            True
# 1                                  False                           False
#
#    PaymentMethod_Mailed check
# 0                       False
# 1                        True
#
# [2 rows x 30 columns]

# %%
# X = X.astype("int")
# y = y.astype("int")

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
X = sc.fit_transform(X)

# %%
X[:2]
# Out:
# array([[-0.44032709, -1.28024804, -1.16169394, -0.99419409, -1.00943013,
#          1.03561683, -0.65230493, -3.05633383,  3.05633383, -0.85433559,
#         -0.88689648, -0.52513044, -0.52513044, -0.63374636, -0.52513044,
#          1.37833008, -0.52513044, -0.72391796, -0.52513044, -0.63926039,
#         -0.52513044, -0.79018582, -0.52513044, -0.79684918, -0.51453688,
#         -0.56136439,  0.82893915, -0.5253508 ,  1.40476387, -0.54360352],
#        [-0.44032709,  0.06430269, -0.26087792, -0.17373982,  0.99065797,
#         -0.9656081 , -0.65230493,  0.32718939, -0.32718939, -0.85433559,
#         -0.88689648, -0.52513044, -0.52513044,  1.57791834, -0.52513044,
#         -0.72551562, -0.52513044,  1.38137199, -0.52513044, -0.63926039,
#         -0.52513044, -0.79018582, -0.52513044, -0.79684918,  1.94349528,
#         -0.56136439, -1.20636117, -0.5253508 , -0.71186341,  1.83957601]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_clf = RandomForestClassifier()

# %%
rf_clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf_pred = rf_clf.predict(X_test)

# %%
rf_clf.score(X_test,rf_pred)
# Out:
# 1.0

# %%
from sklearn.metrics import r2_score,accuracy_score,f1_score

# %%
accuracy_score(y_test,rf_pred)
# Out:
# 0.7837139164153382

# %%
f1_score(y_test,rf_pred,average='micro')
# Out:
# 0.7837139164153382

# %% [markdown]
# # Apply here XgBoost

# %%
y = y.replace({"No": 0, "Yes": 1})
y.astype(int)
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 7032, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
import xgboost as xgb

# %%
from xgboost import XGBClassifier

# %%
clf = xgb.XGBClassifier(
    n_estimators=100,      # Number of boosting rounds
    learning_rate=0.1,     # Step size shrinkage
    max_depth=3,           # Maximum depth of the tree
    # objective='binary:logistic', # For binary classification
    random_state=42
)

# %%
clf.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=3,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
xg_pred = clf.predict(X_test)

# %%
f1_score(y_test,xg_pred,average="micro")
# Out:
# 0.8052563550193882

# %%
accuracy_score(y_test,xg_pred)
# Out:
# 0.8052563550193882

# %%
clf.score(X_test,xg_pred)
# Out:
# 1.0

# %%
r2_score(y_test,xg_pred)
# Out:
# -0.0051566048040163626

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada = AdaBoostClassifier()

# %%
ada.fit(X_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
ada_pred = ada.predict(X_test)

# %%
accuracy_score(y_test,ada_pred)
# Out:
# 0.8013787160706592

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier()

# %%
gbc.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
gbc_pred = gbc.predict(X_test)

# %%
accuracy_score(y_test,gbc_pred)
# Out:
# 0.7996553209823352

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier = Sequential()

# %%
classifier.add(Dense(units=6,activation="relu",kernel_initializer="uniform"))
classifier.add(Dense(units=6,activation="relu",kernel_initializer="uniform"))
classifier.add(Dense(units=6,activation="relu",kernel_initializer="uniform"))

# %%
classifier.add(Dense(units=1,activation="sigmoid",kernel_initializer="uniform"))

# %%
classifier.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])

# %%
history = classifier.fit(X_train, y_train, batch_size=10, epochs=50)
# Out:
# Epoch 1/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 41s 48ms/step - accuracy: 0.7323 - loss: 0.5274
# Epoch 2/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.7663 - loss: 0.4459
# Epoch 3/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 39s 80ms/step - accuracy: 0.7994 - loss: 0.4367
# Epoch 4/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 43s 85ms/step - accuracy: 0.8007 - loss: 0.4311
# Epoch 5/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 63s 131ms/step - accuracy: 0.7994 - loss: 0.4281
# Epoch 6/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 57s 76ms/step - accuracy: 0.7983 - loss: 0.4255
# Epoch 7/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 34s 70ms/step - accuracy: 0.8047 - loss: 0.4236
# Epoch 8/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 49s 101ms/step - accuracy: 0.8026 - loss: 0.4222
# Epoch 9/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 48s 98ms/step - accuracy: 0.8024 - loss: 0.4207
# Epoch 10/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 53s 36ms/step - accuracy: 0.8003 - loss: 0.4203
# Epoch 11/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 41s 86ms/step - accuracy: 0.8026 - loss: 0.4195
# Epoch 12/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 36s 75ms/step - accuracy: 0.8017 - loss: 0.4184
# Epoch 13/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 72s 140ms/step - accuracy: 0.8024 - loss: 0.4183
# Epoch 14/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 65s 105ms/step - accuracy: 0.8020 - loss: 0.4176
# Epoch 15/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 45s 93ms/step - accuracy: 0.8020 - loss: 0.4172
# Epoch 16/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 56s 116ms/step - accuracy: 0.8026 - loss: 0.4163
# Epoch 17/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 67s 82ms/step - accuracy: 0.8015 - loss: 0.4163
# Epoch 18/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 37s 77ms/step - accuracy: 0.8039 - loss: 0.4151
# Epoch 19/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 56s 115ms/step - accuracy: 0.8030 - loss: 0.4153
# Epoch 20/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 52s 109ms/step - accuracy: 0.8034 - loss: 0.4152
# Epoch 21/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 64s 134ms/step - accuracy: 0.8032 - loss: 0.4149
# Epoch 22/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 66s 138ms/step - accuracy: 0.8037 - loss: 0.4130
# Epoch 23/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 59s 122ms/step - accuracy: 0.8062 - loss: 0.4142
# Epoch 24/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 70s 147ms/step - accuracy: 0.8032 - loss: 0.4141
# Epoch 25/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 45s 93ms/step - accuracy: 0.8013 - loss: 0.4139
# Epoch 26/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 54s 114ms/step - accuracy: 0.8026 - loss: 0.4143
# Epoch 27/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 51s 107ms/step - accuracy: 0.8043 - loss: 0.4137
# Epoch 28/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 44s 93ms/step - accuracy: 0.8047 - loss: 0.4128
# Epoch 29/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━ 45s 95ms/step - accuracy: 0.8030 - loss: 0.4135
# Epoch 30/50
# 472/472 ━━━━━━━━━━━━━━━━━━━━